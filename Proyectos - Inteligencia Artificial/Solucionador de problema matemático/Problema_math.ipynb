# %% [markdown]
# **KATERINE LISBETH RAFAEL BOURDIERD 2022-0088**

# %% [markdown]
# A manufacturer makes two models of an item, standard and deluxe. It costs $40  to  manufacture the standard model and $60 for the deluxe. A market research firm estimates that if the standard model is priced at x dollars and the deluxe at y dollars, then the manufacturer will sell 500(y−x)of the standard items and 45,000+500(x−2y) of the deluxe each year. How should the items be priced to maximize profit?

# %%
#Parámetros
tam_poblacion = 10
num_iteraciones = 100
num_padres = 4
tasa_mutacion = 0.6

# %%
def calcular_beneficio(x, y):
    ingreso_estandar = x * 500 * (y - x)
    ingreso_deluxe = y * (45000 + 500 * (x - 2 * y))
    costo_estandar = 40 * 500 * (y - x)
    costo_deluxe = 60 * (45000 + 500 * (x - 2 * y))

    # Calculamos el beneficio restando costos de ingresos
    beneficio = (ingreso_estandar + ingreso_deluxe) - (costo_estandar + costo_deluxe)
    return beneficio

# %%
import random

def inicializar_poblacion(tam_poblacion):
    poblacion = []
    for _ in range(tam_poblacion):
        # precios aleatorios para x , y
        x = int(random.uniform(0, 100))
        y = int(random.uniform(0, 100))
        poblacion.append((x, y))
    return poblacion

# %%
poblacion = inicializar_poblacion(tam_poblacion)
poblacion
# Out:
# [(6, 55),
#  (92, 51),
#  (44, 16),
#  (75, 30),
#  (96, 6),
#  (71, 79),
#  (54, 54),
#  (29, 96),
#  (17, 23),
#  (62, 74)]

# %%
def seleccionar_padres(pob, num_padres):
    padres = sorted(pob, key=lambda ind: calcular_beneficio(ind[0], ind[1]), reverse=True)[:num_padres]
    return padres

# %%
padre = seleccionar_padres(poblacion, num_padres)
padre
# Out:
# [(62, 74), (71, 79), (54, 54), (6, 55)]

# %%
# Función para realizar el cruce de dos padres
def cruce(padre1, padre2):
    hijo = tuple(int((padre1[i] + padre2[i]) / 2) for i in range(len(padre1)))
    return hijo

# %%
padre1 = (81.5, 90.7)
padre2 = (20.4, 67.6)
hijo = cruce(padre1, padre2)

print("Padre 1:", padre1)
print("Padre 2:", padre2)
print("Hijo:", hijo)
# Out:
# Padre 1: (81.5, 90.7)
# Padre 2: (20.4, 67.6)
# Hijo: (50, 79)

# %%
def mutar(individuo, tasa_mutacion):
    for i in range(len(individuo)):
        if random.random() < tasa_mutacion:
            mutacion = int(random.uniform(-20,20))  # Elegir aleatoriamente entre sumar o restar 20
            individuo = individuo[:i] + (individuo[i] + mutacion,) + individuo[i + 1:]
    return individuo

# %%
individuo_inicial = (50.4, 60.4, 70.7, 80.6, 90.7)

individuo_mutado = mutar(individuo_inicial, tasa_mutacion)
print(individuo_mutado)
# Out:
# (64.4, 47.4, 70.7, 72.6, 78.7)

# %%
hijo = (81.5, 67.7)
muta = mutar(hijo, tasa_mutacion)
muta
# Out:
# (87.5, 67.7)

# %%
# Algoritmo genético
for iteracion in range(num_iteraciones):
    print(f"Iteración {iteracion + 1}")

    padre = seleccionar_padres(poblacion, num_padres)
    print("Padres seleccionados:", padre)

    descendencia = []

    for i in range(0, num_padres, 2):
        padre1 = padre[i]
        padre2 = padre[i + 1]

        hijo = cruce(padre1, padre2)
        hijo = mutar(hijo, tasa_mutacion)

        descendencia.append(hijo)

    print("Descendencia generada:", descendencia)

    poblacion = padre + descendencia
    print("Nueva población:", poblacion)

    print("------------------------------")
# Out:
# Iteración 1
# Padres seleccionados: [(62, 74), (71, 79), (54, 54), (6, 55)]
# Descendencia generada: [(77, 76), (30, 54)]
# Nueva población: [(62, 74), (71, 79), (54, 54), (6, 55), (77, 76), (30, 54)]
# ------------------------------
# Iteración 2
# Padres seleccionados: [(62, 74), (71, 79), (77, 76), (54, 54)]
# Descendencia generada: [(54, 68), (69, 49)]
# Nueva población: [(62, 74), (71, 79), (77, 76), (54, 54), (54, 68), (69, 49)]
# ------------------------------
# Iteración 3
# Padres seleccionados: [(62, 74), (71, 79), (54, 68), (77, 76)]
# Descendencia generada: [(82, 70), (65, 78)]
# Nueva población: [(62, 74), (71, 79), (54, 68), (77, 76), (82, 70), (65, 78)]
# ------------------------------
# Iteración 4
# Padres seleccionados: [(62, 74), (65, 78), (71, 79), (54, 68)]
# Descendencia generada: [(63, 76), (62, 64)]
# Nueva población: [(62, 74), (65, 78), (71, 79), (54, 68), (63, 76), (62, 64)]
# ------------------------------
# Iteración 5
# Padres seleccionados: [(62, 74), (63, 76), (65, 78), (71, 79)]
# Descendencia generada: [(62, 75), (51, 78)]
# Nueva población: [(62, 74), (63, 76), (65, 78), (71, 79), (62, 75), (51, 78)]
# ------------------------------
# Iteración 6
# Padres seleccionados: [(62, 74), (62, 75), (63, 76), (65, 78)]
# Descendencia generada: [(54, 74), (74, 58)]
# Nueva población: [(62, 74), (62, 75), (63, 76), (65, 78), (54, 74), (74, 58)]
# ------------------------------
# Iteración 7
# Padres seleccionados: [(62, 74), (62, 75), (63, 76), (65, 78)]
# Descendencia generada: [(62, 91), (83, 77)]
# Nueva población: [(62, 74), (62, 75), (63, 76), (65, 78), (62, 91), (83, 77)]
# ------------------------------
# Iteración 8
# Padres seleccionados: [(62, 74), (62, 75), (63, 76), (65, 78)]
# Descendencia generada: [(62, 66), (75, 77)]
# Nueva población: [(62, 74), (62, 75), (63, 76), (65, 78), (62, 66), (75, 77)]
# ------------------------------
# Iteración 9
# Padres seleccionados: [(62, 74), (62, 75), (63, 76), (65, 78)]
# Descendencia generada: [(62, 74), (64, 77)]
# Nueva población: [(62, 74), (62, 75), (63, 76), (65, 78), (62, 74), (64, 77)]
# ------------------------------
# Iteración 10
# Padres seleccionados: [(62, 74), (62, 74), (62, 75), (63, 76)]
# Descendencia generada: [(50, 74), (62, 75)]
# Nueva población: [(62, 74), (62, 74), (62, 75), (63, 76), (50, 74), (62, 75)]
# ------------------------------
# Iteración 11
# Padres seleccionados: [(62, 74), (62, 74), (62, 75), (62, 75)]
# Descendencia generada: [(62, 59), (43, 69)]
# Nueva población: [(62, 74), (62, 74), (62, 75), (62, 75), (62, 59), (43, 69)]
# ------------------------------
# Iteración 12
# Padres seleccionados: [(62, 74), (62, 74), (62, 75), (62, 75)]
# Descendencia generada: [(62, 65), (71, 81)]
# Nueva población: [(62, 74), (62, 74), (62, 75), (62, 75), (62, 65), (71, 81)]
# ------------------------------
# Iteración 13
# Padres seleccionados: [(62, 74), (62, 74), (62, 75), (62, 75)]
# Descendencia generada: [(62, 92), (62, 58)]
# Nueva población: [(62, 74), (62, 74), (62, 75), (62, 75), (62, 92), (62, 58)]
# ------------------------------
# Iteración 14
# Padres seleccionados: [(62, 74), (62, 74), (62, 75), (62, 75)]
# Descendencia generada: [(62, 74), (56, 86)]
# Nueva población: [(62, 74), (62, 74), (62, 75), (62, 75), (62, 74), (56, 86)]
# ------------------------------
# Iteración 15
# Padres seleccionados: [(62, 74), (62, 74), (62, 74), (62, 75)]
# Descendencia generada: [(62, 80), (73, 62)]
# Nueva población: [(62, 74), (62, 74), (62, 74), (62, 75), (62, 80), (73, 62)]
# ------------------------------
# Iteración 16
# Padres seleccionados: [(62, 74), (62, 74), (62, 74), (62, 75)]
# Descendencia generada: [(65, 74), (62, 65)]
# Nueva población: [(62, 74), (62, 74), (62, 74), (62, 75), (65, 74), (62, 65)]
# ------------------------------
# Iteración 17
# Padres seleccionados: [(65, 74), (62, 74), (62, 74), (62, 74)]
# Descendencia generada: [(63, 70), (74, 74)]
# Nueva población: [(65, 74), (62, 74), (62, 74), (62, 74), (63, 70), (74, 74)]
# ------------------------------
# Iteración 18
# Padres seleccionados: [(65, 74), (62, 74), (62, 74), (62, 74)]
# Descendencia generada: [(63, 59), (62, 74)]
# Nueva población: [(65, 74), (62, 74), (62, 74), (62, 74), (63, 59), (62, 74)]
# ------------------------------
# Iteración 19
# Padres seleccionados: [(65, 74), (62, 74), (62, 74), (62, 74)]
# Descendencia generada: [(63, 74), (69, 74)]
# Nueva población: [(65, 74), (62, 74), (62, 74), (62, 74), (63, 74), (69, 74)]
# ------------------------------
# Iteración 20
# Padres seleccionados: [(65, 74), (63, 74), (62, 74), (62, 74)]
# Descendencia generada: [(72, 74), (66, 74)]
# Nueva población: [(65, 74), (63, 74), (62, 74), (62, 74), (72, 74), (66, 74)]
# ------------------------------
# Iteración 21
# Padres seleccionados: [(65, 74), (63, 74), (62, 74), (62, 74)]
# Descendencia generada: [(64, 74), (62, 74)]
# Nueva población: [(65, 74), (63, 74), (62, 74), (62, 74), (64, 74), (62, 74)]
# ------------------------------
# Iteración 22
# Padres seleccionados: [(64, 74), (65, 74), (63, 74), (62, 74)]
# Descendencia generada: [(64, 74), (62, 74)]
# Nueva población: [(64, 74), (65, 74), (63, 74), (62, 74), (64, 74), (62, 74)]
# ------------------------------
# Iteración 23
# Padres seleccionados: [(64, 74), (64, 74), (65, 74), (63, 74)]
# Descendencia generada: [(64, 85), (50, 74)]
# Nueva población: [(64, 74), (64, 74), (65, 74), (63, 74), (64, 85), (50, 74)]
# ------------------------------
# Iteración 24
# Padres seleccionados: [(64, 74), (64, 74), (65, 74), (63, 74)]
# Descendencia generada: [(64, 67), (71, 86)]
# Nueva población: [(64, 74), (64, 74), (65, 74), (63, 74), (64, 67), (71, 86)]
# ------------------------------
# Iteración 25
# Padres seleccionados: [(64, 74), (64, 74), (65, 74), (63, 74)]
# Descendencia generada: [(51, 58), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (65, 74), (63, 74), (51, 58), (64, 74)]
# ------------------------------
# Iteración 26
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (65, 74)]
# Descendencia generada: [(64, 55), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (65, 74), (64, 55), (64, 74)]
# ------------------------------
# Iteración 27
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(73, 74), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (73, 74), (64, 74)]
# ------------------------------
# Iteración 28
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(80, 74), (52, 78)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (80, 74), (52, 78)]
# ------------------------------
# Iteración 29
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 90), (64, 68)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 90), (64, 68)]
# ------------------------------
# Iteración 30
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 75), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 75), (64, 74)]
# ------------------------------
# Iteración 31
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(51, 82), (64, 64)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (51, 82), (64, 64)]
# ------------------------------
# Iteración 32
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(49, 69), (56, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (49, 69), (56, 74)]
# ------------------------------
# Iteración 33
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 80), (45, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 80), (45, 74)]
# ------------------------------
# Iteración 34
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (72, 86)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (72, 86)]
# ------------------------------
# Iteración 35
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 72), (46, 58)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 72), (46, 58)]
# ------------------------------
# Iteración 36
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(67, 63), (64, 56)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (67, 63), (64, 56)]
# ------------------------------
# Iteración 37
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(57, 77), (56, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (57, 77), (56, 74)]
# ------------------------------
# Iteración 38
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(79, 74), (46, 69)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (79, 74), (46, 69)]
# ------------------------------
# Iteración 39
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(57, 74), (64, 79)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (57, 74), (64, 79)]
# ------------------------------
# Iteración 40
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 61), (69, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 61), (69, 74)]
# ------------------------------
# Iteración 41
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 80), (58, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 80), (58, 74)]
# ------------------------------
# Iteración 42
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(59, 74), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (59, 74), (64, 74)]
# ------------------------------
# Iteración 43
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(59, 74), (48, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (59, 74), (48, 74)]
# ------------------------------
# Iteración 44
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (76, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (76, 74)]
# ------------------------------
# Iteración 45
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (64, 74)]
# ------------------------------
# Iteración 46
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(77, 57), (61, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (77, 57), (61, 74)]
# ------------------------------
# Iteración 47
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(71, 93), (63, 86)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (71, 93), (63, 86)]
# ------------------------------
# Iteración 48
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(62, 56), (64, 76)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (62, 56), (64, 76)]
# ------------------------------
# Iteración 49
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (81, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (81, 74)]
# ------------------------------
# Iteración 50
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (64, 74)]
# ------------------------------
# Iteración 51
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(52, 92), (46, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (52, 92), (46, 74)]
# ------------------------------
# Iteración 52
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(63, 73), (80, 86)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (63, 73), (80, 86)]
# ------------------------------
# Iteración 53
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (64, 74)]
# ------------------------------
# Iteración 54
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(68, 74), (59, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (68, 74), (59, 74)]
# ------------------------------
# Iteración 55
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (64, 74)]
# ------------------------------
# Iteración 56
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(58, 65), (60, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (58, 65), (60, 74)]
# ------------------------------
# Iteración 57
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 90), (64, 58)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 90), (64, 58)]
# ------------------------------
# Iteración 58
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(65, 65), (50, 56)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (65, 65), (50, 56)]
# ------------------------------
# Iteración 59
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(75, 82), (52, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (75, 82), (52, 74)]
# ------------------------------
# Iteración 60
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(49, 74), (70, 71)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (49, 74), (70, 71)]
# ------------------------------
# Iteración 61
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(50, 88), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (50, 88), (64, 74)]
# ------------------------------
# Iteración 62
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(51, 74), (59, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (51, 74), (59, 74)]
# ------------------------------
# Iteración 63
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (64, 61)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (64, 61)]
# ------------------------------
# Iteración 64
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(82, 74), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (82, 74), (64, 74)]
# ------------------------------
# Iteración 65
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(82, 68), (64, 82)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (82, 68), (64, 82)]
# ------------------------------
# Iteración 66
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(61, 74), (64, 70)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (61, 74), (64, 70)]
# ------------------------------
# Iteración 67
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (78, 84)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (78, 84)]
# ------------------------------
# Iteración 68
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 61), (79, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 61), (79, 74)]
# ------------------------------
# Iteración 69
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(50, 60), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (50, 60), (64, 74)]
# ------------------------------
# Iteración 70
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 91), (74, 65)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 91), (74, 65)]
# ------------------------------
# Iteración 71
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (64, 58)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (64, 58)]
# ------------------------------
# Iteración 72
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 60), (77, 56)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 60), (77, 56)]
# ------------------------------
# Iteración 73
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(77, 90), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (77, 90), (64, 74)]
# ------------------------------
# Iteración 74
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 90), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 90), (64, 74)]
# ------------------------------
# Iteración 75
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(79, 62), (66, 62)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (79, 62), (66, 62)]
# ------------------------------
# Iteración 76
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (55, 69)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (55, 69)]
# ------------------------------
# Iteración 77
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(62, 74), (68, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (62, 74), (68, 74)]
# ------------------------------
# Iteración 78
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (56, 89)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (56, 89)]
# ------------------------------
# Iteración 79
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(51, 63), (80, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (51, 63), (80, 74)]
# ------------------------------
# Iteración 80
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (65, 78)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (65, 78)]
# ------------------------------
# Iteración 81
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(48, 55), (52, 60)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (48, 55), (52, 60)]
# ------------------------------
# Iteración 82
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(47, 74), (79, 72)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (47, 74), (79, 72)]
# ------------------------------
# Iteración 83
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (75, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (75, 74)]
# ------------------------------
# Iteración 84
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(82, 74), (45, 55)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (82, 74), (45, 55)]
# ------------------------------
# Iteración 85
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(79, 62), (64, 78)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (79, 62), (64, 78)]
# ------------------------------
# Iteración 86
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 55), (62, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 55), (62, 74)]
# ------------------------------
# Iteración 87
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 66), (65, 76)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 66), (65, 76)]
# ------------------------------
# Iteración 88
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 56), (72, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 56), (72, 74)]
# ------------------------------
# Iteración 89
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (71, 93)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (71, 93)]
# ------------------------------
# Iteración 90
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(56, 74), (64, 58)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (56, 74), (64, 58)]
# ------------------------------
# Iteración 91
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(74, 62), (64, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (74, 62), (64, 74)]
# ------------------------------
# Iteración 92
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(80, 73), (64, 81)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (80, 73), (64, 81)]
# ------------------------------
# Iteración 93
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(63, 74), (64, 75)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (63, 74), (64, 75)]
# ------------------------------
# Iteración 94
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (58, 55)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (58, 55)]
# ------------------------------
# Iteración 95
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 84), (75, 55)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 84), (75, 55)]
# ------------------------------
# Iteración 96
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(67, 74), (67, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (67, 74), (67, 74)]
# ------------------------------
# Iteración 97
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(74, 81), (56, 74)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (74, 81), (56, 74)]
# ------------------------------
# Iteración 98
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 77), (64, 92)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 77), (64, 92)]
# ------------------------------
# Iteración 99
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (60, 86)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (60, 86)]
# ------------------------------
# Iteración 100
# Padres seleccionados: [(64, 74), (64, 74), (64, 74), (64, 74)]
# Descendencia generada: [(64, 74), (54, 72)]
# Nueva población: [(64, 74), (64, 74), (64, 74), (64, 74), (64, 74), (54, 72)]
# ------------------------------

# %%
mejor_individuo = max(poblacion, key=lambda ind: calcular_beneficio(ind[0], ind[1]))
mejor_x, mejor_y = mejor_individuo
mejor_beneficio = calcular_beneficio(mejor_x, mejor_y)

print("Mejor solución encontrada:")
print("Precio modelo estándar:", mejor_x)
print("Precio modelo deluxe:", mejor_y)
print("Beneficio máximo:", mejor_beneficio)
# Out:
# Mejor solución encontrada:
# Precio modelo estándar: 64
# Precio modelo deluxe: 74
# Beneficio máximo: 162000
